# %% [markdown]
# # Load txt file

# %%
import pandas as pd

# %%
filename = "hyp_optimisation.txt"

# %%
with open(filename) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content]

# %% [markdown]
# # Helper functions

# %%
def check_format(line):
    whitelist = ['Job id', 'Train Evaluation summary', 'root_mean', 'Reached prediction', 'Predict Evaluation summary', 
                'Start training iteration', 'num_tree', 'lrn_rate', 'max_dept', 'val_freq']
    for phrase in whitelist:
        if phrase in line:
            if 'Job is success!!' in line:
                return False
            return True
    return False

# %%
def filter_jod_id(line):
    for line in line.split(' '):
        if line.isdigit():
            return line
    raise Exception("Job id not found")

# %% [markdown]
# # Create clean content

# %%
cleaned_content = []
for line in content:
    if check_format(line):
        if 'Job id' in line:
            line = filter_jod_id(line)
        print(line)
        cleaned_content.append(line)
# Out:
# Start training iteration 0
# num_tree: 30
# lrn_rate: 0.172
# max_dept: 30
# val_freq: 15
# 2021072411355058935654
# Train Evaluation summary:
# "root_mean_squared_error": 0.18990151808549874
# "root_mean_squared_error": 17.78257939198001
# Reached prediction
# 2021072412160053345157
# Predict Evaluation summary:
# "root_mean_squared_error": 31.992399700130317
# Start training iteration 1
# num_tree: 30
# lrn_rate: 0.224
# max_dept: 20
# val_freq: 15
# 2021072412164698702458
# Train Evaluation summary:
# "root_mean_squared_error": 0.030257388542796852
# "root_mean_squared_error": 16.342188673895766
# Reached prediction
# 2021072412481482651361
# Predict Evaluation summary:
# "root_mean_squared_error": 31.502618917043
# Start training iteration 2
# num_tree: 40
# lrn_rate: 0.274
# max_dept: 45
# val_freq: 10
# 2021072412485911012662
# Train Evaluation summary:
# "root_mean_squared_error": 0.014188182367871645
# "root_mean_squared_error": 17.586666063809698
# Reached prediction
# 2021072413234569364265
# Predict Evaluation summary:
# "root_mean_squared_error": 31.96563250893371
# Start training iteration 3
# num_tree: 40
# lrn_rate: 0.225
# max_dept: 35
# val_freq: 15
# 2021072413242462433666
# Train Evaluation summary:
# "root_mean_squared_error": 0.013718553882693862
# "root_mean_squared_error": 17.44854554038651
# Reached prediction
# 2021072414040294065469
# Predict Evaluation summary:
# "root_mean_squared_error": 31.067461497814158
# Start training iteration 4
# num_tree: 30
# lrn_rate: 0.132
# max_dept: 30
# val_freq: 10
# 2021072414044872635370
# Train Evaluation summary:
# "root_mean_squared_error": 0.7497131447960708
# "root_mean_squared_error": 18.401373633293975
# Reached prediction
# 2021072414421270801273
# Predict Evaluation summary:
# "root_mean_squared_error": 32.12920018270268
# Start training iteration 5
# num_tree: 20
# lrn_rate: 0.146
# max_dept: 35
# val_freq: 15
# 2021072414425758447574
# Train Evaluation summary:
# "root_mean_squared_error": 2.173746318842628
# "root_mean_squared_error": 18.6545465769647
# Reached prediction
# 2021072415081119226477
# Predict Evaluation summary:
# "root_mean_squared_error": 36.28295187411222
# Start training iteration 6
# num_tree: 30
# lrn_rate: 0.01
# max_dept: 40
# val_freq: 10
# 2021072415084848580078
# Train Evaluation summary:
# "root_mean_squared_error": 35.86253333563753
# "root_mean_squared_error": 36.15604052130937
# Reached prediction
# 2021072415513760260981
# Predict Evaluation summary:
# "root_mean_squared_error": 41.663403057866326
# Start training iteration 7
# num_tree: 40
# lrn_rate: 0.067
# max_dept: 10
# val_freq: 15
# 2021072415522346842382
# Train Evaluation summary:
# "root_mean_squared_error": 3.261952798399225
# "root_mean_squared_error": 15.52809219531935
# Reached prediction
# 2021072416193919513285
# Predict Evaluation summary:
# "root_mean_squared_error": 29.88408341795246
# Start training iteration 8
# num_tree: 20
# lrn_rate: 0.058
# max_dept: 20
# val_freq: 15
# 2021072416202854280586
# Train Evaluation summary:
# "root_mean_squared_error": 14.668558090810434
# "root_mean_squared_error": 22.97365037241541
# Reached prediction
# 2021072416413123988489
# Predict Evaluation summary:
# "root_mean_squared_error": 33.66278413518056
# Start training iteration 9
# num_tree: 20
# lrn_rate: 0.207
# max_dept: 10
# val_freq: 15
# 2021072416420561030990
# Train Evaluation summary:
# "root_mean_squared_error": 0.6318062370622123
# "root_mean_squared_error": 15.659267087385702
# Reached prediction
# 2021072416554351465393
# Predict Evaluation summary:
# "root_mean_squared_error": 32.64882743752538
# Start training iteration 0
# num_tree: 20
# lrn_rate: 0.026
# max_dept: 25
# val_freq: 15
# 2021072417202689697694
# Train Evaluation summary:
# "root_mean_squared_error": 28.204782543814808
# "root_mean_squared_error": 32.869706744503894
# Reached prediction
# 2021072417415977086197
# Predict Evaluation summary:
# "root_mean_squared_error": 37.121005509578964
# Start training iteration 1
# num_tree: 85
# lrn_rate: 0.016
# max_dept: 45
# val_freq: 20
# 2021072417423716026298
# Train Evaluation summary:
# "root_mean_squared_error": 12.469606592363325
# "root_mean_squared_error": 20.201365303854235
# Reached prediction
# 20210724193537486667101
# Predict Evaluation summary:
# "root_mean_squared_error": 32.248774658755174
# Start training iteration 2
# num_tree: 55
# lrn_rate: 0.091
# max_dept: 35
# val_freq: 10
# 20210724193655247750102
# Train Evaluation summary:
# "root_mean_squared_error": 0.2796045158067063
# "root_mean_squared_error": 18.991308635645357
# Reached prediction
# 20210724204601790646105
# Predict Evaluation summary:
# "root_mean_squared_error": 34.205866734421015
# Start training iteration 3
# num_tree: 60
# lrn_rate: 0.021
# max_dept: 20
# val_freq: 20
# 20210724204706229885106
# Train Evaluation summary:
# "root_mean_squared_error": 13.653806720605598
# "root_mean_squared_error": 21.817753039462527
# Reached prediction
# 20210724214811306323109
# Predict Evaluation summary:
# "root_mean_squared_error": 32.987445262537946
# Start training iteration 4
# num_tree: 45
# lrn_rate: 0.021
# max_dept: 20
# val_freq: 10
# 20210724214920147982110
# Train Evaluation summary:
# "root_mean_squared_error": 18.587566445164573
# "root_mean_squared_error": 26.514096248051573
# Reached prediction
# 20210724223330969855113
# Predict Evaluation summary:
# "root_mean_squared_error": 35.35227932683867
# Start training iteration 5
# num_tree: 60
# lrn_rate: 0.051
# max_dept: 25
# val_freq: 20
# 20210724223427000617114
# Train Evaluation summary:
# "root_mean_squared_error": 2.2107195681349388
# "root_mean_squared_error": 17.19993053772836
# Reached prediction
# 20210724234100230315117
# Predict Evaluation summary:
# "root_mean_squared_error": 32.12516189850764
# Start training iteration 6
# num_tree: 95
# lrn_rate: 0.016
# max_dept: 15
# val_freq: 20
# 20210724234204170011118
# Train Evaluation summary:
# "root_mean_squared_error": 10.556458943324133
# "root_mean_squared_error": 20.703425095082896
# Reached prediction
# 20210725011303439600121
# Predict Evaluation summary:
# "root_mean_squared_error": 33.43644193996282
# Start training iteration 0
# num_tree: 45
# lrn_rate: 0.041
# max_dept: 40
# val_freq: 10
# 202107251403415946681
# Train Evaluation summary:
# "root_mean_squared_error": 7.434908189634454
# "root_mean_squared_error": 18.379508940092652
# Reached prediction
# 202107251457200153574
# Predict Evaluation summary:
# "root_mean_squared_error": 32.31388023221106
# Start training iteration 1
# num_tree: 50
# lrn_rate: 0.001
# max_dept: 15
# val_freq: 20
# 202107251458143752975
# Train Evaluation summary:
# "root_mean_squared_error": 45.520061067027996
# "root_mean_squared_error": 45.87510391357293
# Reached prediction
# 202107251538027986108
# Predict Evaluation summary:
# "root_mean_squared_error": 45.12198649683955
# Start training iteration 2
# num_tree: 85
# lrn_rate: 0.021
# max_dept: 30
# val_freq: 25
# 202107251538591691009
# Train Evaluation summary:
# "root_mean_squared_error": 7.992581606313015
# "root_mean_squared_error": 17.586165468299402
# Reached prediction
# 2021072517092639519012
# Predict Evaluation summary:
# "root_mean_squared_error": 32.05649233942582
# Start training iteration 3
# num_tree: 95
# lrn_rate: 0.026
# max_dept: 30
# val_freq: 25
# 2021072517104761728313
# Train Evaluation summary:
# "root_mean_squared_error": 4.087842089828729
# "root_mean_squared_error": 20.337635643874318
# Reached prediction
# 2021072518533246270216
# Predict Evaluation summary:
# "root_mean_squared_error": 32.68717530955637
# Start training iteration 4
# num_tree: 75
# lrn_rate: 0.026
# max_dept: 35
# val_freq: 20
# 2021072518545887535317
# Train Evaluation summary:
# "root_mean_squared_error": 6.826525924945822
# "root_mean_squared_error": 19.988491059052457
# Reached prediction
# 2021072520230329657020
# Predict Evaluation summary:
# "root_mean_squared_error": 33.21039171144744
# Start training iteration 5
# num_tree: 85
# lrn_rate: 0.051
# max_dept: 30
# val_freq: 20
# 2021072520241853895921
# Train Evaluation summary:
# "root_mean_squared_error": 0.600587435655712
# "root_mean_squared_error": 18.571079169738514
# Reached prediction
# 2021072522054257201424
# Predict Evaluation summary:
# "root_mean_squared_error": 32.34512360835902
# Start training iteration 0
# num_tree: 30
# lrn_rate: 0.11
# max_dept: 35
# val_freq: 25
# 202107261420068827508
# Train Evaluation summary:
# "root_mean_squared_error": 1.5613362441296006
# "root_mean_squared_error": 18.17360302101053
# Reached prediction
# 2021072615025371573811
# Predict Evaluation summary:
# "root_mean_squared_error": 34.48937707070364
# Start training iteration 1
# num_tree: 35
# lrn_rate: 0.01
# max_dept: 5
# val_freq: 20
# 2021072615034149425912
# Train Evaluation summary:
# "root_mean_squared_error": 35.246128936077675
# "root_mean_squared_error": 35.79350297348894
# Reached prediction
# 2021072615141777673415
# Predict Evaluation summary:
# "root_mean_squared_error": 39.64544503509825
# Start training iteration 2
# num_tree: 30
# lrn_rate: 0.06
# max_dept: 5
# val_freq: 15
# 2021072615145211970716
# Train Evaluation summary:
# "root_mean_squared_error": 13.436318986391813
# "root_mean_squared_error": 17.329562518222943
# Reached prediction
# 2021072615243810170819
# Predict Evaluation summary:
# "root_mean_squared_error": 31.391680362566238
# Start training iteration 0
# num_tree: 30
# lrn_rate: 0.11
# max_dept: 15
# val_freq: 20
# 2021072615291020321720
# Train Evaluation summary:
# "root_mean_squared_error": 1.5525537487350203
# "root_mean_squared_error": 16.291123611697465
# Reached prediction
# 2021072615594145067823
# Predict Evaluation summary:
# "root_mean_squared_error": 31.69336954918455
# Start training iteration 1
# num_tree: 35
# lrn_rate: 0.01
# max_dept: 45
# val_freq: 25
# 2021072616004343643724
# Train Evaluation summary:
# "root_mean_squared_error": 33.69003562143959
# "root_mean_squared_error": 35.655649507713484
# Reached prediction
# 2021072616450587600627
# Predict Evaluation summary:
# "root_mean_squared_error": 40.117092685017084
# Start training iteration 2
# num_tree: 35
# lrn_rate: 0.16
# max_dept: 30
# val_freq: 10
# 2021072616454924676728
# Train Evaluation summary:
# "root_mean_squared_error": 0.12350604590638202
# "root_mean_squared_error": 17.834249321007867
# Reached prediction
# 2021072617280705887931
# Predict Evaluation summary:
# "root_mean_squared_error": 31.752615427594336
# Start training iteration 3
# num_tree: 30
# lrn_rate: 0.06
# max_dept: 10
# val_freq: 15
# 2021072617290160024632
# Train Evaluation summary:
# "root_mean_squared_error": 7.932364304704135
# "root_mean_squared_error": 17.27968740061514
# Reached prediction
# 2021072617482575511135
# Predict Evaluation summary:
# "root_mean_squared_error": 31.694490177005694
# Start training iteration 4
# num_tree: 30
# lrn_rate: 0.16
# max_dept: 20
# val_freq: 20
# 2021072617490458383236
# Train Evaluation summary:
# "root_mean_squared_error": 0.28948778509182344
# "root_mean_squared_error": 19.663545636667344
# Reached prediction
# 2021072618224841106639
# Predict Evaluation summary:
# "root_mean_squared_error": 34.02353230017859
# Start training iteration 5
# num_tree: 30
# lrn_rate: 0.01
# max_dept: 45
# val_freq: 15
# 2021072618233502931040
# Train Evaluation summary:
# "root_mean_squared_error": 35.52938593807055
# "root_mean_squared_error": 36.7479609730301
# Reached prediction
# 2021072619012316249743
# Predict Evaluation summary:
# "root_mean_squared_error": 40.27365194601923
# Start training iteration 6
# num_tree: 30
# lrn_rate: 0.16
# max_dept: 20
# val_freq: 25
# 2021072619020684581444
# Train Evaluation summary:
# "root_mean_squared_error": 0.28481125497702936
# "root_mean_squared_error": 19.865097451360505
# Reached prediction
# 2021072619345515927047
# Predict Evaluation summary:
# "root_mean_squared_error": 31.730930502038504
# Start training iteration 7
# num_tree: 30
# lrn_rate: 0.06
# max_dept: 15
# val_freq: 10
# 2021072619354592400448
# Train Evaluation summary:
# "root_mean_squared_error": 7.682027536210485
# "root_mean_squared_error": 18.425090852161627
# Reached prediction
# 2021072620042532887051
# Predict Evaluation summary:
# "root_mean_squared_error": 32.24499305253033
# Start training iteration 8
# num_tree: 30
# lrn_rate: 0.11
# max_dept: 20
# val_freq: 15
# 2021072620050893087452
# Train Evaluation summary:
# "root_mean_squared_error": 1.553743059144821
# "root_mean_squared_error": 17.94000043441738
# Reached prediction
# 2021072620375591631355
# Predict Evaluation summary:
# "root_mean_squared_error": 32.12502142597092
# Start training iteration 9
# num_tree: 30
# lrn_rate: 0.16
# max_dept: 10
# val_freq: 15
# 2021072620384476891656
# Train Evaluation summary:
# "root_mean_squared_error": 0.42762739721234355
# "root_mean_squared_error": 16.620165952229016
# Reached prediction
# 2021072621010220243259
# Predict Evaluation summary:
# "root_mean_squared_error": 30.758806438787136
# Start training iteration 0
# num_tree: 30
# lrn_rate: 0.06
# max_dept: 20
# val_freq: 10
# 2021072702020914352360
# Train Evaluation summary:
# "root_mean_squared_error": 7.768662244346339
# "root_mean_squared_error": 20.829465838467282
# Reached prediction
# 2021072702355166852063
# Predict Evaluation summary:
# "root_mean_squared_error": 34.110006880616396
# Start training iteration 1
# num_tree: 30
# lrn_rate: 0.16
# max_dept: 20
# val_freq: 25
# 2021072702363469195064
# Train Evaluation summary:
# "root_mean_squared_error": 0.2887769072105894
# "root_mean_squared_error": 18.75317602898238
# Reached prediction
# 2021072703095607154967
# Predict Evaluation summary:
# "root_mean_squared_error": 34.998281383749266
# Start training iteration 2
# num_tree: 35
# lrn_rate: 0.06
# max_dept: 40
# val_freq: 10
# 2021072703103958935068
# Train Evaluation summary:
# "root_mean_squared_error": 5.646830857195836
# "root_mean_squared_error": 20.810883181730777
# Reached prediction
# 2021072703550050910371
# Predict Evaluation summary:
# "root_mean_squared_error": 31.44245397865132
# Start training iteration 3
# num_tree: 35
# lrn_rate: 0.11
# max_dept: 20
# val_freq: 10
# 2021072703554896517672
# Train Evaluation summary:
# "root_mean_squared_error": 0.8894154103851061
# "root_mean_squared_error": 19.642630785531495
# Reached prediction
# 2021072704461213885175
# Predict Evaluation summary:
# "root_mean_squared_error": 31.47445725548482
# Start training iteration 4
# num_tree: 30
# lrn_rate: 0.11
# max_dept: 45
# val_freq: 20
# 2021072704470261113376
# Train Evaluation summary:
# "root_mean_squared_error": 1.562029767157902
# "root_mean_squared_error": 17.50949958194651
# Reached prediction
# 2021072705312097562979
# Predict Evaluation summary:
# "root_mean_squared_error": 32.501095963810926
# Start training iteration 5
# num_tree: 35
# lrn_rate: 0.16
# max_dept: 40
# val_freq: 25
# 2021072705322054528680
# Train Evaluation summary:
# "root_mean_squared_error": 0.12392665709449541
# "root_mean_squared_error": 17.994414970812407
# Reached prediction
# 2021072706191949888183
# Predict Evaluation summary:
# "root_mean_squared_error": 30.99594302355366
# Start training iteration 6
# num_tree: 30
# lrn_rate: 0.06
# max_dept: 35
# val_freq: 10
# 2021072706200577394584
# Train Evaluation summary:
# "root_mean_squared_error": 7.784195762291588
# "root_mean_squared_error": 18.966838965937956
# Reached prediction
# 2021072706564555885487
# Predict Evaluation summary:
# "root_mean_squared_error": 32.40509627849046
# Start training iteration 7
# num_tree: 30
# lrn_rate: 0.06
# max_dept: 30
# val_freq: 25
# 2021072706573057027288
# Train Evaluation summary:
# "root_mean_squared_error": 7.706612742662764
# "root_mean_squared_error": 18.654684041030855
# Reached prediction
# 2021072707315357888291
# Predict Evaluation summary:
# "root_mean_squared_error": 30.414034000276164
# Start training iteration 8
# num_tree: 30
# lrn_rate: 0.11
# max_dept: 5
# val_freq: 20
# 2021072707323824568292
# Train Evaluation summary:
# "root_mean_squared_error": 8.341806147686096
# "root_mean_squared_error": 15.09895669000373
# Reached prediction
# 2021072707414923544895
# Predict Evaluation summary:
# "root_mean_squared_error": 28.767862850234387
# Start training iteration 9
# num_tree: 35
# lrn_rate: 0.01
# max_dept: 5
# val_freq: 20
# 2021072707421988862796
# Train Evaluation summary:
# "root_mean_squared_error": 34.96382537734565
# "root_mean_squared_error": 36.7262614112535
# Reached prediction
# 2021072707531369885199
# Predict Evaluation summary:
# "root_mean_squared_error": 39.22055553221777
# Start training iteration 0
# num_tree: 35
# lrn_rate: 0.16
# max_dept: 5
# val_freq: 20
# 202107271302153259391
# Train Evaluation summary:
# "root_mean_squared_error": 4.853825118715574
# "root_mean_squared_error": 16.87593733064093
# Reached prediction
# 202107271312212010264
# Predict Evaluation summary:
# "root_mean_squared_error": 30.822404002224715
# Start training iteration 1
# num_tree: 35
# lrn_rate: 0.06
# max_dept: 10
# val_freq: 25
# 202107271312505586985
# Train Evaluation summary:
# "root_mean_squared_error": 5.791965969329147
# "root_mean_squared_error": 18.030277355529453
# Reached prediction
# 202107271333541606248
# Predict Evaluation summary:
# "root_mean_squared_error": 30.53153769723832
# Start training iteration 2
# num_tree: 30
# lrn_rate: 0.01
# max_dept: 45
# val_freq: 20
# 202107271335013050759
# Train Evaluation summary:
# "root_mean_squared_error": 35.67837868384081
# "root_mean_squared_error": 37.156570979999074
# Reached prediction
# 2021072714085522581212
# Predict Evaluation summary:
# "root_mean_squared_error": 41.257240301888416
# Start training iteration 3
# num_tree: 30
# lrn_rate: 0.11
# max_dept: 5
# val_freq: 25
# 2021072714092960072813
# Train Evaluation summary:
# "root_mean_squared_error": 7.914928639369858
# "root_mean_squared_error": 14.310831759028856
# Reached prediction
# 2021072714182624960816
# Predict Evaluation summary:
# "root_mean_squared_error": 26.583807744447228

# %% [markdown]
# # Convert to df

# %%
header = ['num_tree', 'lrn_rate', 'max_dept', 'val_freq', 'train_job_id', 
          'train_rmse', 'validate_rmse', 'pred_job_id', 'pred_rmse']

# %%
rows = []

# %%
temp = []
for line in cleaned_content:
    if 'Start training' in line:
        if not temp:
            continue
        rows.append(temp)
        temp = []
        continue
    if 'Evaluation' in line:
        continue
    if 'prediction' in line:
        continue
    if line.isdigit():  # if line is job id
        temp.append(line)
    else:
        number = float(line.split(' ')[1])
        temp.append(f'{number:.2f}')

# %%
df = pd.DataFrame(rows, columns=header)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   num_tree       49 non-null     object
#  1   lrn_rate       49 non-null     object
#  2   max_dept       49 non-null     object
#  3   val_freq       49 non-null     object
#  4   train_job_id   49 non-null     object
#  5   train_rmse     49 non-null     object
#  6   validate_rmse  49 non-null     object
#  7   pred_job_id    49 non-null     object
#  8   pred_rmse      49 non-null     object
# dtypes: object(9)
# memory usage: 3.6+ KB

# %%
arranged_header = ['train_job_id', 'pred_job_id', 'num_tree', 'lrn_rate', 'max_dept', 'val_freq', 
                   'train_rmse', 'validate_rmse', 'pred_rmse']

# %%
df = df[arranged_header]
df.sort_values(['pred_rmse'], ascending=[True], inplace=True)
df.reset_index(inplace=True, drop=True)
df
# Out:
#                train_job_id              pred_job_id num_tree lrn_rate  \
# 0    2021072707323824568292   2021072707414923544895    30.00     0.11
# 1    2021072415522346842382   2021072416193919513285    40.00     0.07
# 2    2021072706573057027288   2021072707315357888291    30.00     0.06
# 3     202107271312505586985    202107271333541606248    35.00     0.06
# 4    2021072620384476891656   2021072621010220243259    30.00     0.16
# 5     202107271302153259391    202107271312212010264    35.00     0.16
# 6    2021072705322054528680   2021072706191949888183    35.00     0.16
# 7    2021072413242462433666   2021072414040294065469    40.00     0.23
# 8    2021072615145211970716   2021072615243810170819    30.00     0.06
# 9    2021072703103958935068   2021072703550050910371    35.00     0.06
# 10   2021072703554896517672   2021072704461213885175    35.00     0.11
# 11   2021072412164698702458   2021072412481482651361    30.00     0.22
# 12   2021072615291020321720   2021072615594145067823    30.00     0.11
# 13   2021072617290160024632   2021072617482575511135    30.00     0.06
# 14   2021072619020684581444   2021072619345515927047    30.00     0.16
# 15   2021072616454924676728   2021072617280705887931    35.00     0.16
# 16   2021072412485911012662   2021072413234569364265    40.00     0.27
# 17   2021072411355058935654   2021072412160053345157    30.00     0.17
# 18    202107251538591691009   2021072517092639519012    85.00     0.02
# 19  20210724223427000617114  20210724234100230315117    60.00     0.05
# 20   2021072620050893087452   2021072620375591631355    30.00     0.11
# 21   2021072414044872635370   2021072414421270801273    30.00     0.13
# 22   2021072619354592400448   2021072620042532887051    30.00     0.06
# 23   2021072417423716026298  20210724193537486667101    85.00     0.02
# 24    202107251403415946681    202107251457200153574    45.00     0.04
# 25   2021072520241853895921   2021072522054257201424    85.00     0.05
# 26   2021072706200577394584   2021072706564555885487    30.00     0.06
# 27   2021072704470261113376   2021072705312097562979    30.00     0.11
# 28   2021072416420561030990   2021072416554351465393    20.00     0.21
# 29   2021072517104761728313   2021072518533246270216    95.00     0.03
# 30  20210724204706229885106  20210724214811306323109    60.00     0.02
# 31   2021072518545887535317   2021072520230329657020    75.00     0.03
# 32  20210724234204170011118  20210725011303439600121    95.00     0.02
# 33   2021072416202854280586   2021072416413123988489    20.00     0.06
# 34   2021072617490458383236   2021072618224841106639    30.00     0.16
# 35   2021072702020914352360   2021072702355166852063    30.00     0.06
# 36  20210724193655247750102  20210724204601790646105    55.00     0.09
# 37    202107261420068827508   2021072615025371573811    30.00     0.11
# 38   2021072702363469195064   2021072703095607154967    30.00     0.16
# 39  20210724214920147982110  20210724223330969855113    45.00     0.02
# 40   2021072414425758447574   2021072415081119226477    20.00     0.15
# 41   2021072417202689697694   2021072417415977086197    20.00     0.03
# 42   2021072707421988862796   2021072707531369885199    35.00     0.01
# 43   2021072615034149425912   2021072615141777673415    35.00     0.01
# 44   2021072616004343643724   2021072616450587600627    35.00     0.01
# 45   2021072618233502931040   2021072619012316249743    30.00     0.01
# 46    202107271335013050759   2021072714085522581212    30.00     0.01
# 47   2021072415084848580078   2021072415513760260981    30.00     0.01
# 48    202107251458143752975    202107251538027986108    50.00     0.00
#
#    max_dept val_freq train_rmse validate_rmse pred_rmse
# 0      5.00    20.00       8.34         15.10     28.77
# 1     10.00    15.00       3.26         15.53     29.88
# 2     30.00    25.00       7.71         18.65     30.41
# 3     10.00    25.00       5.79         18.03     30.53
# 4     10.00    15.00       0.43         16.62     30.76
# 5      5.00    20.00       4.85         16.88     30.82
# 6     40.00    25.00       0.12         17.99     31.00
# 7     35.00    15.00       0.01         17.45     31.07
# 8      5.00    15.00      13.44         17.33     31.39
# 9     40.00    10.00       5.65         20.81     31.44
# 10    20.00    10.00       0.89         19.64     31.47
# 11    20.00    15.00       0.03         16.34     31.50
# 12    15.00    20.00       1.55         16.29     31.69
# 13    10.00    15.00       7.93         17.28     31.69
# 14    20.00    25.00       0.28         19.87     31.73
# 15    30.00    10.00       0.12         17.83     31.75
# 16    45.00    10.00       0.01         17.59     31.97
# 17    30.00    15.00       0.19         17.78     31.99
# 18    30.00    25.00       7.99         17.59     32.06
# 19    25.00    20.00       2.21         17.20     32.13
# 20    20.00    15.00       1.55         17.94     32.13
# 21    30.00    10.00       0.75         18.40     32.13
# 22    15.00    10.00       7.68         18.43     32.24
# 23    45.00    20.00      12.47         20.20     32.25
# 24    40.00    10.00       7.43         18.38     32.31
# 25    30.00    20.00       0.60         18.57     32.35
# 26    35.00    10.00       7.78         18.97     32.41
# 27    45.00    20.00       1.56         17.51     32.50
# 28    10.00    15.00       0.63         15.66     32.65
# 29    30.00    25.00       4.09         20.34     32.69
# 30    20.00    20.00      13.65         21.82     32.99
# 31    35.00    20.00       6.83         19.99     33.21
# 32    15.00    20.00      10.56         20.70     33.44
# 33    20.00    15.00      14.67         22.97     33.66
# 34    20.00    20.00       0.29         19.66     34.02
# 35    20.00    10.00       7.77         20.83     34.11
# 36    35.00    10.00       0.28         18.99     34.21
# 37    35.00    25.00       1.56         18.17     34.49
# 38    20.00    25.00       0.29         18.75     35.00
# 39    20.00    10.00      18.59         26.51     35.35
# 40    35.00    15.00       2.17         18.65     36.28
# 41    25.00    15.00      28.20         32.87     37.12
# 42     5.00    20.00      34.96         36.73     39.22
# 43     5.00    20.00      35.25         35.79     39.65
# 44    45.00    25.00      33.69         35.66     40.12
# 45    45.00    15.00      35.53         36.75     40.27
# 46    45.00    20.00      35.68         37.16     41.26
# 47    40.00    10.00      35.86         36.16     41.66
# 48    15.00    20.00      45.52         45.88     45.12
